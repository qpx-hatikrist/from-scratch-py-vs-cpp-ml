# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('..\\data\\regression\\AMES_Final_DF.csv')

# %%
X = df.drop('SalePrice', axis=1)
y = df['SalePrice']

# %%
def train_test_split(X, y, test_size=0.3, shuffle=True):
    length = len(X)
    length_test_size = length*test_size
    X_test = X.loc[length - length_test_size-1:]
    X_train = X.loc[:length - length_test_size]
    return X_test

# %%
train_test_split(X, y)
# Out:
#       Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year Built  \
# 2047     75.000000     11235             5             5        1964
# 2048     62.000000     14299             4             3        1964
# 2049     61.000000      7943             4             5        1961
# 2050     65.000000     14149             5             8        1964
# 2051     74.551020     11677             5             4        1966
# ...            ...       ...           ...           ...         ...
# 2920     37.000000      7937             6             6        1984
# 2921     75.144444      8885             5             5        1983
# 2922     62.000000     10441             5             5        1992
# 2923     77.000000     10010             5             5        1974
# 2924     74.000000      9627             7             5        1993
#
#       Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
_, X_test, _, _ = train_test_split(X, y, test_size=0.3, shuffle=False)
X_test
# Out:
#       Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year Built  \
# 2047     75.000000     11235             5             5        1964
# 2048     62.000000     14299             4             3        1964
# 2049     61.000000      7943             4             5        1961
# 2050     65.000000     14149             5             8        1964
# 2051     74.551020     11677             5             4        1966
# ...            ...       ...           ...           ...         ...
# 2920     37.000000      7937             6             6        1984
# 2921     75.144444      8885             5             5        1983
# 2922     62.000000     10441             5             5        1992
# 2923     77.000000     10010             5             5        1974
# 2924     74.000000      9627             7             5        1993
#
#       Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# ...
